# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

def func(Pt, Kd, c, Eps, Lt):
    return (1/2*(Kd + Lt + Pt - np.sqrt((Kd + Lt + Pt)**2 - 4*Lt*Pt)))*Eps + c

Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]

popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1, 0.05, 0.055, 3.8], bounds=(0, [1, 0.1, 0.1, 5]))

print(popt)

#perr = np.sqrt(np.diag(pcov))

#plt.plot(Pt, ydata, 'b.', label='data')
ymodel=[]
for val in Pt:
    ymodel.append(func(val, *popt))

#Kd=50 nM
ymodel_kd_50=[]

def func(Pt, c):
    return (1/2*(.05+ 3.211 + Pt - np.sqrt((.05 + 3.211 + Pt)**2 - 4*3.211*Pt)))*0.0618 + c
Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]
popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1], bounds=(0, [10]))

for val in Pt:
    ymodel_kd_50.append(func(val, *popt))

#Kd=100 nM  
ymodel_kd_100=[]
def func(Pt, c):
    return (1/2*(.1+ 3.211 + Pt - np.sqrt((.1 + 3.211 + Pt)**2 - 4*3.211*Pt)))*0.0618 + c
Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]
popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1], bounds=(0, [10]))

for val in Pt:
    ymodel_kd_100.append(func(val, *popt))

#Kd=120 nM  
ymodel_kd_150=[]
def func(Pt, c):
    return (1/2*(.15+ 3.211 + Pt - np.sqrt((.15 + 3.211 + Pt)**2 - 4*3.211*Pt)))*0.0618 + c
Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]
popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1], bounds=(0, [10]))

for val in Pt:
    ymodel_kd_150.append(func(val, *popt))

#Kd=200 nM  
ymodel_kd_200=[]
def func(Pt, c):
    return (1/2*(.2+ 3.211 + Pt - np.sqrt((.2 + 3.211 + Pt)**2 - 4*3.211*Pt)))*0.0618 + c
Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]
popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1], bounds=(0, [10]))

for val in Pt:
    ymodel_kd_200.append(func(val, *popt))

#Kd=500 nM  
ymodel_kd_500=[]
def func(Pt, c):
    return (1/2*(.5+ 3.211 + Pt - np.sqrt((.5 + 3.211 + Pt)**2 - 4*3.211*Pt)))*0.0618 + c
Pt = [0, 0.384, 0.768, 1.15, 1.53, 1.91, 2.29, 2.67, 3.05, 3.42, 3.80, 4.73, 5.67, 6.59, 7.51, 11.1]
ydata = [0.053, 0.101, 0.112, 0.131, 0.152, 0.172, 0.193, 0.204, 0.224, 0.235, 0.244, 0.248, 0.254, 0.2548, 0.256, 0.262]
popt, pcov = curve_fit(func, Pt, ydata, p0=[0.1], bounds=(0, [10]))

for val in Pt:
    ymodel_kd_500.append(func(val, *popt))


patch_list=[]
fig=[]
fig, ax = plt.subplots(figsize=(10,10))
plt.plot(Pt, ydata, 'b.', label='data', markersize=15)
plt.plot(Pt, ymodel, 'r-', color = 'red', label='fit: Kd = 122 nM')
plt.plot(Pt, ymodel_kd_50, 'r-', color = 'purple', label='50 nM')
patch_list.append(Patch(facecolor='red', label='50 nM'))
plt.plot(Pt, ymodel_kd_100, 'r-', color = 'magenta', label='100 nM')
patch_list.append(Patch(facecolor='red', label='100 nM'))
plt.plot(Pt, ymodel_kd_150, 'r-', color = 'blue', label='150 nM')
patch_list.append(Patch(facecolor='red', label='150 nM'))
plt.plot(Pt, ymodel_kd_200, 'r-', color = 'green', label='200 nM')
patch_list.append(Patch(facecolor='red', label='200 nM'))
plt.plot(Pt, ymodel_kd_500, 'r-', color = 'black', label='500 nM')
patch_list.append(Patch(facecolor='red', label='500 nM'))
plt.xlabel('[MPP1, µM]')
plt.ylabel('Abs463')
plt.legend()
plt.show()
# Out:
# [0.12184595 0.06458745 0.06176167 3.21127899]
